# %%
# %load_ext autoreload
# %autoreload 2

# %%
from pathlib import Path

from brisc.manuscript_analysis.utils import get_output_folder

DATA_ROOT = "/Volumes/BlackPasspo/brisc/brisc"
save_path = get_output_folder(DATA_ROOT)
# If in the lab, set DATA_ROOT to None, we'll find the data with flexiznam

# optional, can be None or the path to arial.ttf:
arial_font_path = None  # "/nemo/lab/znamenskiyp/home/shared/resources/fonts/arial.ttf"

save_path = Path(save_path)
save_path.mkdir(exist_ok=True)

# %%
# Add data_root to sys.path, to find the config.yml file
import sys

sys.path.append(DATA_ROOT)

# %%
import iss_analysis as iss_analysis
import matplotlib
import matplotlib.font_manager as fm
import matplotlib.patches as patches
import matplotlib.pyplot as plt
import numpy as np
import scanpy as sc
from iss_preprocess.io import (
    get_processed_path,
    load_ops,
)
from iss_preprocess.pipeline.sequencing import (
    basecall_tile,
)
from tqdm import tqdm

from brisc.manuscript_analysis import cell_typing, load, overview_image
from brisc.manuscript_analysis import spatial_plots_rabies as spatial
from brisc.manuscript_analysis.gene_transcript_plots import plot_gene_expression_mosaic

# set matplotlib options
if arial_font_path is not None:
    arial_prop = fm.FontProperties(fname=arial_font_path)
    plt.rcParams["font.family"] = arial_prop.get_name()
    plt.rcParams.update({"mathtext.default": "regular"})  # make math mode also Arial
    fm.fontManager.addfont(arial_font_path)

matplotlib.rcParams["pdf.fonttype"] = 42  # for pdfs

# %%
# Load rabies and barcode rounds from tile
ops = load_ops("becalia_rabies_barseq/BRAC8498.3e/chamber_08")

rabies_rounds_stack, _, _ = basecall_tile(
    "becalia_rabies_barseq/BRAC8498.3e/chamber_08", (2, 2, 3), save_spots=False
)
cropped_rabies_cells = rabies_rounds_stack[1250:1550, 1750:2050, :, :].copy()
del rabies_rounds_stack

# %%
# Actual color of dots
# because of bleedthrough, bases are not just 1 colors. Plot the actual value for legends

bleedthrough = np.load(
    get_processed_path("becalia_rabies_barseq/BRAC8498.3e/chamber_08")
    / "barcode_cluster_means.npy"
)
rnd_1 = bleedthrough[0]
channel_colors = np.array(
    [[0, 0.8, 0], [0, 0.6, 1], [1, 0, 1], [1.0, 0.9, 0]],
    dtype=float,  # 1, 1, 0], [1, 0, 1], [0, 1, 1], [1, 1, 1]
)
channel_colors = channel_colors[::-1].copy()
base_colors = [base @ channel_colors for base in rnd_1]
base_colors = [b / b.max() for b in base_colors]
ax = plt.subplot(111, facecolor="k")
for ibase, name in enumerate("GTAC"):
    col = base_colors[ibase]
    ax.text(ibase, 0.25, name, color=channel_colors[ibase], fontsize=100)
    ax.text(ibase, 0, name, color=col / col.max(), fontsize=100)
    plt.xlim(-0.5, 4.5)
    plt.ylim(-0.1, 0.5)
plt.xticks([])
plt.yticks([])

# %%
image_dict = {}

vmax_dict = {
    "rab": (25000, 23000, 23000, 23000),  # "rab": (23000, 23000, 23000, 23000),
    "genes": (26000, 25000, 25000, 25000),
    "mCherry": (7000, 3500),
    "hyb": (5000, 3000, 7000, 2000),
    "hyb2": (100000, 100000, 100000, 8000),
}

vmin_dict = {
    "rab": (17050, 17050, 17050, 17050),  # "rab": (17000, 17000, 17000, 17000),
    "genes": (18500, 18500, 18500, 18500),
    "mCherry": (10, 10),
}

colors_dict = {
    "rab": channel_colors,
    "genes": channel_colors,
    "mCherry": ([1, 0, 0], [0, 1, 1]),
}

downsampling_dict = {
    "rab": 4,
    "genes": 1,
    "mCherry": 2,
}
for image in tqdm(["rab", "genes", "mCherry"]):
    downsampled_path = get_processed_path(
        f"becalia_rabies_barseq/BRAC8498.3e/chamber_08/manual_starter_click/BRAC8498.3e_chamber_08_2_{image}_downsampled.npy"
    )
    colors_path = downsampled_path.with_name(
        f"{downsampled_path.stem}_channel_colors.npy"
    )
    expected_colors = np.asarray(colors_dict[image], dtype=float)
    colors_match = image == "mCherry" or (
        colors_path.exists() and np.array_equal(np.load(colors_path), expected_colors)
    )
    if downsampled_path.exists() and colors_match and True == False:
        print(f"Loading downsampled {image} image")
        # These cached arrays total >12 GiB; memory-map instead of reading them all.
        rgb = np.load(downsampled_path, mmap_mode="r")
    else:
        processed_path = get_processed_path(
            f"becalia_rabies_barseq/BRAC8498.3e/chamber_08/manual_starter_click/BRAC8498.3e_chamber_08_2_{image}.tif"
        )
        print(f"Making downsampled RGB for {image} image with current colours")
        rgb = overview_image.make_downsampled_rgb(
            processed_path,
            downsample_factor=downsampling_dict[image],
            channel_colors=colors_dict[image],
            vmax=vmax_dict[image],
            vmin=vmin_dict[image],
            channel_order=(
                np.argsort(ops["camera_order"]) if image in {"rab", "genes"} else None
            ),
        )
        np.save(
            downsampled_path,
            rgb,
        )
        if image != "mCherry":
            np.save(colors_path, expected_colors)

    image_dict[image] = rgb

# %%
# Load cell clustering data for UMAPs
processed_path = get_processed_path(
    "becalia_rabies_barseq/BRAC8498.3e/analysis/adata_q.h5ad"
)
adata_backed = sc.read_h5ad(processed_path, backed="r")


processed_path = get_processed_path(
    "becalia_rabies_barseq/BRAC8498.3e/analysis/BRAC8498.3e_error_corrected_barcodes_26_cell_barcode_df.pkl"
)

cells_df = load.load_cell_barcode_data(
    processed_path,
    areas_to_empty=["fiber tracts", "outside"],
    valid_areas=["Isocortex", "TH"],
    distance_threshold=150,
)
filtered_ids = set(cells_df.index)
umap_obs = adata_backed.obs[["custom_leiden"]].copy()
umap_obs["in_filtered_df"] = umap_obs.index.isin(filtered_ids)
umap_obs["in_filtered_df"] = umap_obs["in_filtered_df"].where(
    umap_obs["in_filtered_df"]
)

# UMAP plotting only needs these two columns and the 2-D embedding. Keeping the
# full AnnData also retains PCA, neighbour graphs, and other multi-GB arrays.
adata_umap = sc.AnnData(
    obs=umap_obs,
    obsm={"X_umap": np.asarray(adata_backed.obsm["X_umap"], dtype=np.float32)},
)
adata_umap.uns["custom_leiden_colors"] = adata_backed.uns["custom_leiden_colors"]
adata_backed.file.close()
del adata_backed, umap_obs

# %%
cm = 1 / 2.54
fontsize_dict = {"title": 7, "label": 8, "tick": 6, "legend": 6}

# every plotting function returns what it drew; collect it here
plotted = {}
line_width = 0.5
line_alpha = 1

fig, axes = plt.subplot_mosaic(
    [
        ["mCherry", "mCherry", "rab", "rab", "rab", "rab"],
        ["genes", "genes", "rab", "rab", "rab", "rab"],
        [
            "rab_round1",
            "rab_round2",
            "UMAP_clust",
            "UMAP_clust",
            "UMAP_bar",
            "UMAP_bar",
        ],
        [
            "rab_round9",
            "rab_round10",
            "UMAP_clust",
            "UMAP_clust",
            "UMAP_bar",
            "UMAP_bar",
        ],
    ],
    figsize=(17.4 * cm, 14 * cm),
    dpi=300,
    gridspec_kw={
        "width_ratios": [1, 1, 1, 1, 1, 1],
        "height_ratios": [1, 1, 0.5, 0.5],
        "wspace": 0.1,
        "hspace": 0.1,
    },
)

inset_downsample_factor = 5
inset_frac = 0.40
offset_frac = 0.03
outer_col = "white"
inner_col = "white"
outer_lw = 1
inner_lw = 0.8

inner_specs = {
    "mCherry": {"tl": (0.21, 0.46), "h": 0.22},
    "genes": {"tl": (0.21, 0.46), "h": 0.22},
}
default_spec = {"tl": (0.30, 0.30), "h": 0.40}

scalebar_um = {"rab": 250, "mCherry": 50, "genes": 50}

# Crop of whole image onto rabies region
x0, x1 = 0.307, 0.518
y0, y1 = 0.279, 0.485

# First do rab (to get aspect), then mCherry, then genes
rab_aspect = None
for key in ["rab", "mCherry", "genes"]:
    ax = axes[key]
    img = image_dict[key]
    H, W = img.shape[:2]

    # Coordinates of the outer crop (same for all three channels)
    x0_px = int(x0 * W)
    x1_px = int(x1 * W)
    y0_px = int(y0 * H)
    y1_px = int(y1 * H)

    # Rabies, no inset but draw dotted box on the main crop
    if key == "rab":
        main_crop = img[y0_px:y1_px, x0_px:x1_px]
        rab_aspect = (x1_px - x0_px) / (y1_px - y0_px)

        ax.imshow(main_crop, interpolation="none")

        # Draw dotted rectangle that marks the zoom-in used by mCherry/genes
        spec = inner_specs.get("mCherry", default_spec)
        tlx, tly = spec["tl"]
        h_frac = spec["h"]

        owH, owW = main_crop.shape[:2]
        box_h = int(h_frac * owH)
        box_w = int(box_h * rab_aspect)
        if box_w > owW:
            box_w = owW
            box_h = int(box_w / rab_aspect)

        x0_in = np.clip(int(tlx * owW), 0, owW - box_w)
        y0_in = np.clip(int(tly * owH), 0, owH - box_h)

        # Add rectangle for zoom-in to genes/mcherry
        ax.add_patch(
            patches.Rectangle(
                (x0_in, y0_in),
                box_w,
                box_h,
                linewidth=inner_lw,
                edgecolor=inner_col,
                linestyle="dotted",
                facecolor="none",
            )
        )

        # Add rectangle for rabies cells rounds
        ax.add_patch(
            patches.Rectangle(
                (x0_in, y0_in + 130),
                80,  # width
                80,  # height
                linewidth=inner_lw,
                edgecolor=inner_col,
                linestyle="dotted",
                facecolor="none",
            )
        )

        if key in scalebar_um:
            overview_image.add_scalebar(
                ax,
                downsample_factor=downsampling_dict[key],
                length_um=scalebar_um[key],
            )

        overview_image.print_image_stats(
            key,
            main_crop,
            pixel_size_um=0.231,
            downsample_factor=downsampling_dict[key],
        )
        ax.axis("off")
        continue

    outer_crop = img[y0_px:y1_px, x0_px:x1_px]

    # --------- dotted rectangle spec inside the OUTER crop --------
    spec = inner_specs.get(key, default_spec)
    tlx, tly = spec["tl"]
    h_frac = spec["h"]

    owH, owW = outer_crop.shape[:2]
    box_h = int(h_frac * owH)
    box_w = int(box_h * rab_aspect)
    if box_w > owW:  # keep aspect consistent
        box_w = owW
        box_h = int(box_w / rab_aspect)
    x0_in = np.clip(int(tlx * owW), 0, owW - box_w)
    y0_in = np.clip(int(tly * owH), 0, owH - box_h)

    # zoomed-in region from rabies for genes/mcherry panel
    main_crop = outer_crop[y0_in : y0_in + box_h, x0_in : x0_in + box_w]
    ax.imshow(main_crop, interpolation="none")

    # add scale-bar
    if key in scalebar_um:
        overview_image.add_scalebar(
            ax,
            downsample_factor=downsampling_dict[key],
            length_um=scalebar_um[key],
        )
    ax.axis("off")
    overview_image.print_image_stats(
        key,
        main_crop,
        pixel_size_um=0.231,
        downsample_factor=downsampling_dict[key],
    )

    # ------------------------------------------------------
    # INSET ─ show a **further 5× down-sampled** view of the
    #         SAME outer_crop; no interpolation this time.
    # ------------------------------------------------------
    outer_crop_ds = overview_image.downsample_xy(outer_crop, inset_downsample_factor)

    # inset axes placement identical to before
    bbox = ax.get_position()
    pw, ph = bbox.width, bbox.height
    iw, ih = pw * inset_frac, ph * inset_frac
    ix = bbox.x0 - pw * offset_frac
    iy = bbox.y1 + ph * offset_frac - ih
    axins = fig.add_axes([ix, iy, iw, ih])
    axins.set(xticks=[], yticks=[])

    # display *down-sampled* inset
    if key == "mCherry":
        axins.imshow(np.clip(outer_crop_ds / 0.5, 0, 1), interpolation="none")
    elif key == "genes":
        axins.imshow(np.clip(outer_crop_ds / 1.5, 0, 1), interpolation="none")

    # pretty border around inset
    for sp in axins.spines.values():
        sp.set_visible(True)
        sp.set_edgecolor(outer_col)
        sp.set_linewidth(outer_lw)

    # dotted rectangle marking zoom-in MUST be scaled to the
    # down-sampled resolution
    scale = 1 / inset_downsample_factor
    axins.add_patch(
        patches.Rectangle(
            (x0_in * scale, y0_in * scale),
            box_w * scale,
            box_h * scale,
            linewidth=inner_lw,
            edgecolor=inner_col,
            # linestyle="dotted",
            facecolor="none",
        )
    )

overview_image.plot_selected_rounds(
    [
        axes["rab_round1"],
        axes["rab_round2"],
        axes["rab_round9"],
        axes["rab_round10"],
    ],
    cropped_rabies_cells,
    selected_rounds=[1, 2, 9, 10],
    fontsize=fontsize_dict["legend"],
    vmin=np.array([0.0, 0.0, 0.0, 0.0]),
    vmax=np.array(
        [0.7, 0.4, 0.35, 0.6]
    ),  # R, G, M, C [0.4, 0.4, 0.35, 0.3] y,m,c,w [0.3, 0.3, 0.1, 0.5]
    channel_colors=channel_colors,
)

overview_image.add_scalebar(
    axes["rab_round10"],
    downsample_factor=1,
    length_um=20,
)

overview_image.print_image_stats(
    "rab_rounds",
    cropped_rabies_cells,
    pixel_size_um=0.231,
    downsample_factor=1,
)

plotted["umap_clusters"] = cell_typing.plot_cell_clusters(
    adata_umap,
    axes["UMAP_clust"],
    spot_size=1,
    fontsize=4,
    font_outline=0.5,
)
plotted["umap_barcoded_cells"] = cell_typing.plot_umap_barcoded_cells(
    adata_umap,
    axes["UMAP_bar"],
    size_non_barcoded=1,
    size_barcoded=0.5,
    legend_fontsize=6,
)

# Everything plotted in Fig.2, keyed by panel. Images and scalebars are not
# collected, only the data-bearing panels.
fig2_plotted_data = plotted

plt.savefig(
    save_path / "rabies_barseq_overview.pdf",
    dpi=600,
)
# plt.close(fig)

# %%
processed_path = get_processed_path(
    "becalia_rabies_barseq/BRAC8498.3e/analysis/adata_q.h5ad"
)
selected_genes = [
    "Calb1",
    "Ctgf",
    "Dgkb",
    "Igfbp4",
    "Lamp5",
    "Nov",
    "Nr4a2",
    "Pcp4",
    "Sst",
    "Vip",
]

# Read metadata without loading all matrices, then materialize only the cells
# used in the gene-expression panel. This reduces 1,954,128 cells to ~432k.
adata_backed = sc.read_h5ad(processed_path, backed="r")
cell_mask = (
    ~adata_backed.obs["custom_leiden"].isin(["Car3", "VLMC", "Unassigned"])
    & adata_backed.obs["chamber"].isin(["chamber_07"])
    & ~adata_backed.obs["area_acronym"].isin(["outside"])
)
cell_mask = cell_mask.to_numpy()
gene_indices = adata_backed.raw.var_names.get_indexer(selected_genes)
expression = adata_backed.raw.X[cell_mask, :][:, gene_indices]
plot_obs = adata_backed.obs.loc[
    cell_mask, ["ara_y", "ara_z", "chamber", "area_acronym"]
].copy()
adata = sc.AnnData(
    X=expression,
    obs=plot_obs,
)
adata.var_names = selected_genes
adata.raw = adata
adata_backed.file.close()
del adata_backed, expression, plot_obs

atlas_size = 10

# Prepare bin_image for contour plotting
bin_image = spatial.prepare_area_labels(
    xpos=830,
    structures=[
        # Cortical plate layers (Allen CCF acronyms)
        "root",
        "CTX",
        "MB",
        "DG",
        "DG-mo",
        "DG-sg",
        "SCdg",
        "SCdw",
        "SCig",
        "SCiw",
        "SCop",
        "SCsg",
        "SCzo",
        "PAG",
        "MRN",
        "TH",
        "RN",
    ],
    atlas_size=10,
)

# %%
fontsize_dict = {"title": 7, "label": 8, "tick": 6, "legend": 6}
plt.rcParams.update(
    {
        "axes.titlesize": fontsize_dict["title"],
        "axes.labelsize": fontsize_dict["label"],
        "xtick.labelsize": fontsize_dict["tick"],
        "ytick.labelsize": fontsize_dict["tick"],
        "legend.fontsize": fontsize_dict["legend"],
        "legend.title_fontsize": fontsize_dict["legend"],
    }
)

cm = 1 / 2.54
fig = plt.figure(figsize=(17.4 * cm, 5.8 * cm), dpi=300, constrained_layout=True)
gs = fig.add_gridspec(nrows=1, ncols=1)

genes, axes, gene_expression_plotted = plot_gene_expression_mosaic(
    fig,
    gs[0],
    adata=adata,
    bin_image=bin_image,
    genes=selected_genes,
    fontsize_dict=fontsize_dict,
    atlas_size=atlas_size,
    use_raw=True,
    percentile=95,
    s=0.3,
    ncols=5,
    cmaps=[
        "GnBu",
        "Oranges",
        "Greys",
        "Blues",
        "Reds",
        "pink_r",
        "Purples",
        "Greens",
        "Wistia",
        "RdPu",
    ],
    chambers=["chamber_07"],
    border_linewidth=0.5,
)


# Add 1 mm scale bar to the top-left of each subplot.
import matplotlib.patches as mpatches

scale_bar_length = 1000 / atlas_size
margin = 15  # offset from axis edge, in axis units

for ax in axes[-1:]:
    x_left, x_right = ax.get_xlim()
    y_top, y_bottom = ax.get_ylim()

    # top-left corner visually is high x_data, low y_data
    bar_x_start = max(x_left, x_right) - margin - scale_bar_length
    bar_y = min(y_top, y_bottom) + margin

    bar = mpatches.FancyBboxPatch(
        (bar_x_start, bar_y),
        scale_bar_length,
        15,  # bar height in axis units (~90 µm, thin line)
        boxstyle="square,pad=0",
        facecolor="k",
        edgecolor="none",
        zorder=20,
    )
    ax.add_patch(bar)
    ax.text(
        bar_x_start + scale_bar_length / 2,
        bar_y + 20,
        "1 mm",
        ha="center",
        va="top",
        fontsize=fontsize_dict["tick"],
        color="k",
        zorder=20,
    )

fig2_plotted_data["gene_expression"] = gene_expression_plotted

plt.show()
fig.savefig(
    save_path / "fig2_extension_selected_gene_expression_2x5.pdf", bbox_inches="tight"
)

# %%
from brisc import source_data

source_data.export_fig2_source_data(
    save_path / "Source_Data" / "Source_Data_Figure_2.xlsx",
    fig2_plotted_data=fig2_plotted_data,
)
